# %%
import matplotlib
import matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import path
from imageio import imread
import matplotlib.pyplot as plt
import random

# %%
xData=pd.read_csv('PredictDataset.csv')

# %%
#YEAR ANALYSIS :
sns.set(rc = {'figure.figsize':(15,8)})
sns.stripplot(y="year", x="ratingInteger", data=xData, jitter=True);
print('RATING BASED ON YEAR')
plt.show()
# Out:
# RATING BASED ON YEAR

# %%
sns.stripplot(y="year", x="nrOfUserReviews", data=xData, jitter=True);
print('NO. OF USER REVIEWS BASED ON YEAR')
# Out:
# NO. OF USER REVIEWS BASED ON YEAR

# %%
#REVENUE BASED ON YEAR
sns.stripplot(y="year", x="lifetime_gross", data=xData, jitter=True);
print('REVENUE BASED ON YEAR')
